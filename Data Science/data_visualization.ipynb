# %% [markdown]
# **Data Visualization**

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=plt.axis()
plt.show()

# %% [markdown]
# ### Line Plot

# %% [markdown]
# A line plot displays data along a number line, a useful tool to track changes over short and long periods of time.

# %%
import numpy as np
x=np.linspace(0,10,1000)
y=np.sin(x)
fig=plt.figure()
ax=plt.axis()
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('function sin(x)')
plt.show()

# %%
from matplotlib.projections.polar import PolarTransform
x=np.linspace(0,10,1000)
y=np.cos(x)
fig=plt.figure()
ax=plt.axis()
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('function cos(x)')
plt.show()

# %%
#multiple lines plotting
x=np.linspace(0,10,1000)
y=np.sin(x)
plt.plot(x,np.sin(x),linestyle='--',color='k',label='sin(x)')
plt.plot(x,np.cos(x),color='r',label='cos(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('function of sin and cos')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

presidents_df = pd.read_csv('https://sololearn.com/uploads/files/president_heights_party.csv', index_col='name')
plt.scatter(presidents_df['height'], presidents_df['age'],color='k')
plt.xlabel('height')
plt.ylabel('age')
plt.title('US presidents height')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

presidents_df = pd.read_csv('https://sololearn.com/uploads/files/president_heights_party.csv', index_col='name')
plt.scatter(presidents_df['height'], presidents_df['age'],color='k',marker='<')
plt.xlabel('height')
plt.ylabel('age')
plt.title('US presidents height')
plt.show()

# %%
presidents_df.head(5)
# Out:
#                    order  age  height                  party
# name
# George Washington      1   57     189                   none
# John Adams             2   61     170             federalist
# Thomas Jefferson       3   57     189  democratic-republican
# James Madison          4   57     163  democratic-republican
# James Monroe           5   58     183  democratic-republican

# %%
presidents_df.plot(
    kind='scatter',
    x='height',
    y='age',
    color='k',
    marker='<',
    title='USA Presidents'
)

# %% [markdown]
# ### Histogram

# %%
presidents_df['height'].plot(
    kind='hist',
    bins=5,
    title='height'
)

# %% [markdown]
# ### BOX Plot

# %%
'''
The corresponding boxplot is shown below. The blue box indicates the interquartile range (IQR, between the first quartile and the third),
in other words, 50% data fall in this range.
The red bar shows the median, and the lower and upper black whiskers are minimum and maximum
'''
plt.style.use('classic')
presidents_df.boxplot(column='height')

# %% [markdown]
# ### Bar Plot

# %%
party_count=presidents_df['party'].value_counts()
print(party_count)
# Out:
# republican               19
# democratic               15
# democratic-republican     4
# whig                      4
# none                      1
# federalist                1
# national union            1
# Name: party, dtype: int64

# %%
plt.style.use('ggplot')
party_count.plot(
    kind='bar',
    color='k',
    title='party'
)

# %%
plt.style.use('ggplot')
party_count.plot(
    kind='barh',
    color='k',
    title='party'
)
